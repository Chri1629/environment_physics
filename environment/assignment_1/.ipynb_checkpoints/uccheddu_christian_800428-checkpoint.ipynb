# %% [markdown]
# # ASSIGNMENT 1
#
# **NOME:** Christian
#
# **COGNOME:** Uccheddu
#
# **MATRICOLA:** 800428

# %% [markdown]
# First the necessary libraries are imported in which the relative versions are also printed so that everything is reproducible.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt

pd.options.mode.chained_assignment = None

print("Pandas version:",pd.__version__)
print("Geoandas version:",gpd.__version__)
print("Matplotlib version:",matplotlib.__version__)
# Out:
# Pandas version: 1.2.3
# Geoandas version: 0.8.1
# Matplotlib version: 3.3.4

# %% [markdown]
# We then import the shapefile containing the information on the municipalities in Lombardy in 2012. We also print the first observation to see how it is structured.

# %%
shapefile = "./REGIONE_LOMBARDIA/Comuni_2012.shp"
comuni = gpd.read_file(shapefile)
print(comuni.iloc[0])
# Out:
# CLASSREF                   1e9d907b-5ca6-413c-a9a9-323051719aa5
# BELFIORE                                                   H870
# COD_ISTAT                                              03020056
# NOME_COM                              SAN GIACOMO DELLE SEGNATE
# COD_PRO                                                      20
# NOME_PRO                                                MANTOVA
# COD_CMO                                                    None
# NOME_CMO                                                   None
# COD_ASL                                                       7
# NOME_ASL                                                MANTOVA
# COD_REG                                                      03
# NOME_REG                                              LOMBARDIA
# SHAPE_AREA                                         16636352.943
# SHAPE_LEN                                          23465.214759
# geometry      POLYGON ((659751.4091499997 4979669.499609999,...
# ...

# %% [markdown]
# We select only the municipalities belonging to the province of Milan and show a quick plot

# %%
milano = comuni[comuni.NOME_PRO == 'MILANO']
milano.plot(color = "skyblue", figsize = (8,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# We also import the file relating to the population present in each municipality of Lombardy both in 2011 and in 2014. This data is fundamental because density of population is defined as follows:
#
# $$density=\frac{people}{Area}$$
#
# Where the Area is taken from the first file and the number of inhabitants is taken from this file.

# %%
tab_pop = pd.read_csv('./REGIONE_LOMBARDIA/Lombardia_Pop2011_2014.csv',sep=',',encoding= 'unicode_escape')
print(tab_pop.head())
# Out:
#     Codice                Comune  Cod_prov Provincia  Pop2011  Pop2014
# 0  3017064               CORZANO        17   BRESCIA   1358.0   1427.0
# 1  3017167               RUDIANO        17   BRESCIA   5861.0   5822.0
# 2  3017201  VILLANUOVA SUL CLISI        17   BRESCIA   5855.0   5778.0
# 3  3017084                  IRMA        17   BRESCIA    152.0    128.0
# 4  3017102     MANERBA DEL GARDA        17   BRESCIA   4985.0   5290.0

# %% [markdown]
# Now let's select only the cities belonging to the province of milan and rename the **Codice** attribute so that it has the same name as the relative attribute in the previous dataframe so that we are able to merge them more easily.

# %%
tab_pop = tab_pop.loc[tab_pop['Provincia'] == 'MILANO']
tab_pop.rename(columns={'Codice':'COD_ISTAT'}, inplace=True)

# %% [markdown]
# We then merge the two dataframes using the **COD\_ISTAT** attribute as the key. We also print the first row of the dataframe to see that it contains all the fields that interest us.

# %%
tab_pop.COD_ISTAT = tab_pop.COD_ISTAT.astype(int)
milano.COD_ISTAT = milano.COD_ISTAT.astype(int)
milano_density = milano.merge(tab_pop, on='COD_ISTAT')
print(milano_density.iloc[0])
# Out:
# CLASSREF                   109334ca-566a-46f4-8830-fa1f79665a45
# BELFIORE                                                   L773
# COD_ISTAT                                               3015236
# NOME_COM                                                VERNATE
# COD_PRO                                                      15
# NOME_PRO                                                 MILANO
# COD_CMO                                                    None
# NOME_CMO                                                   None
# COD_ASL                                                      10
# NOME_ASL                                               MILANO 2
# COD_REG                                                      03
# NOME_REG                                              LOMBARDIA
# SHAPE_AREA                                        14676883.3089
# SHAPE_LEN                                          24400.493214
# geometry      POLYGON ((505377.5921999998 5020478.00575, 505...
# ...

# %% [markdown]
# Now let's calculate the density in all the cities in the province of Milan using:
#
# $$density=\frac{people}{Area}$$
#
# >We also remember that the Area in the shapefile is defined in $m^2$. By convention, however, population densities are expressed in $\frac{peop}{km^2}$. Precisely for this reason we pass from $m^2$ to $km^2$ dividing Area for $10^6$.

# %%
milano_density['density2011'] = round(milano_density['Pop2011']/(milano_density['geometry'].area/(10**6)),2)

# %% [markdown]
# We then plot the population density in the area in the province of Milan using a color map that allows us to highlight the differences between the municipalities. As expected, in fact, all the most densely populated areas are those located close to Milan and the density decreases moving away from the latter.

# %%
ax = milano_density.plot(column = milano_density['density2011'], cmap = 'bwr', legend=True,
            legend_kwds={'label': r'Density of population (peop/$km^2$)'}, figsize = (8,8))
ax.figure.savefig("milano.png", dpi = 400, bbox_inches='tight')

# %% [markdown]
# ## SMALL ADDITION
#
# As proof of what we have said previously, we show a scatter plot in which we see the correlation between the distance from Milan and the population density.

# %%
milano_density['distanza'] = milano_density.centroid.apply(lambda g: milano_density.centroid[89].distance(g))
milano_density['distanza'] = milano_density['distanza']/1000

# %%
from scipy import stats
import seaborn as sns

fig= plt.figure(figsize = (10,6))

slope, intercept, r_value, p_value, std_err = stats.linregress(milano_density['distanza'], y = milano_density['density2011'])
sns.regplot(x = milano_density['distanza'], y = milano_density['density2011'], scatter_kws={"s": 30}, ci = 95, color = "#FFAD89", order = 1,
            line_kws={'label': r"y={0:.2f}x+{1:.2f}, $r^2$ = {2:.2f}, p = {3:.2f}".format(slope, intercept, r_value, p_value)})

plt.xticks(size = 12)
plt.yticks(size = 12)

plt.xlabel("Distance (km)", size = 15)
plt.ylabel(r'Density of population (peop/$km^2$)', size = 15)

plt.ylim(bottom = 0)
plt.grid()
plt.legend(fontsize=12)
plt.savefig("scatter.png", dpi = 400, bbox_inches='tight')

# %% [markdown]
# As we can see there is a strong negative correlation between Density of Population and the distance from Milan with a significant p-value (< 0.05), so our hypothesis is well founded.
