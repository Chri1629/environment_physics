# %% [markdown]
# # ASSIGNMENT 3
#
# **NOME:** Christian
#
# **COGNOME:** Uccheddu
#
# **MATRICOLA:** 800428
#
# > This assignment is based on the code of Prof. Samuel Albani left during the lessons.

# %% [markdown]
# First the necessary libraries are imported in which the relative versions are also printed so that everything is reproducible.

# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
from scipy import stats
import scipy
import seaborn as sns
import seaborn
from pylab import *

import datetime as dtm
from datetime import datetime

import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import matplotlib
import cartopy
import xarray as xr

pd.options.mode.chained_assignment = None

print("Pandas version:",pd.__version__)
print("Numpy version:",np.__version__)
print("Cartopy version:",cartopy.__version__)
print("Geoandas version:",gpd.__version__)
print("Matplotlib version:",matplotlib.__version__)
print("Scipy version:",scipy.__version__)
print("Seaborn version:",sns.__version__)
print("Xarray version:",xr.__version__)
# Out:
# Pandas version: 1.2.3
# Numpy version: 1.19.2
# Cartopy version: 0.18.0
# Geoandas version: 0.8.1
# Matplotlib version: 3.3.4
# Scipy version: 1.6.1
# Seaborn version: 0.11.1
# Xarray version: 0.17.0

# %% [markdown]
# ## Per prima cosa apro i dati dell'assignment 2.
#
# In modo da avere solo i dati che ci servono successivamente faccio ensemble dei 4 modelli della lezione 3

# %%
gmta_2 = pd.read_csv("gmta.csv", sep = ",", index_col=[0])
gmta_2 = gmta_2.loc[(gmta_2['time'] >= "1901") & (gmta_2['time'] <= "2015")]

# %% [markdown]
# Prendiamo i dati solo dal 1901 in poi per confrontarlo

# %%
gmta_2
# Out:
#            time      gmta
# 51   1901-12-31 -0.242510
# 52   1902-12-31 -0.510430
# 53   1903-12-31 -0.500922
# 54   1904-12-31 -0.557091
# 55   1905-12-31 -0.370764
# ..          ...       ...
# 160  2010-12-31  1.013360
# 161  2011-12-31  0.945926
# 162  2012-12-31  0.872095
# 163  2013-12-31  0.846080
# 164  2014-12-31  0.963406
#
# [114 rows x 2 columns]

# %% [markdown]
# ## Importo i dati per i modelli ensemble

# %%
modfile='dati/ts_Amon_IPSL-CM6A-LR_historical_r1i1p1f1_gr_185001-201412.nc'
modfile2='dati/ts_Amon_MRI-ESM2-0_historical_r1i1p1f1_gn_185001-201412.nc'
modfile3='dati/ts_Amon_MIROC6_historical_r1i1p1f1_gn_185001-194912.nc'
modfile4='dati/ts_Amon_MIROC6_historical_r1i1p1f1_gn_195001-201412.nc'

# %% [markdown]
# Cerco di metterli nella stessa griglia e metterli in un xarray

# %%
d1d = xr.open_dataset(modfile)
ts1 = d1d.ts  

d2d = xr.open_dataset(modfile2)
ts2 = d2d.ts  

d3d = xr.open_dataset(modfile3)
ts3 = d3d.ts  

d4d = xr.open_dataset(modfile4)
ts4 = d4d.ts  
print('\n','>>>>>>>>>>>>','\n',ts4)
# Out:
#  >>>>>>>>>>>>
#  <xarray.DataArray 'ts' (time: 780, lat: 128, lon: 256)>
# [25559040 values with dtype=float32]
# Coordinates:
#   * time     (time) datetime64[ns] 1950-01-16T12:00:00 ... 2014-12-16T12:00:00
#   * lat      (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon      (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Attributes:
#     standard_name:  surface_temperature
#     long_name:      Surface Temperature
#     comment:        Temperature of the lower boundary of the atmosphere
#     units:          K
#     original_name:  GRTS
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella
#     history:        2018-11-30T16:15:29Z altered by CMOR: replaced missing va...

# %%
m5 = xr.concat([ts3, ts4], dim = "time")
m5
# Out:
# <xarray.DataArray 'ts' (time: 1980, lat: 128, lon: 256)>
# array([[[256.965  , 256.93384, 256.9114 , ..., 257.05728, 257.02985,
#          256.99744],
#         [257.96994, 257.86023, 257.76547, ..., 258.29037, 258.1906 ,
#          258.0809 ],
#         [258.96613, 258.87885, 258.7891 , ..., 259.31274, 259.19055,
#          259.10327],
#         ...,
#         [243.79747, 244.01567, 244.25256, ..., 243.13542, 243.36234,
#          243.58302],
#         [242.01204, 242.12051, 242.22774, ..., 241.6405 , 241.75146,
#          241.89609],
#         [240.32138, 240.35379, 240.38622, ..., 240.2129 , 240.2553 ,
#          240.2902 ]],
#
#        [[241.27107, 241.24857, 241.22104, ..., 241.27733, 241.3036 ,
#          241.29485],
#         [240.9008 , 240.79947, 240.69814, ..., 241.18727, 241.09344,
#          240.99837],
#         [241.28609, 241.14098, 240.99712, ..., 241.71391, 241.5688 ,
#          241.42744],
# ...
#         [251.51785, 251.65811, 251.81026, ..., 251.03883, 251.20287,
#          251.35739],
#         [251.21594, 251.28012, 251.34074, ..., 251.021  , 251.08638,
#          251.15651],
#         [251.10065, 251.1054 , 251.11728, ..., 251.05191, 251.06854,
#          251.08876]],
#
#        [[258.32196, 258.30713, 258.29105, ..., 258.37762, 258.36032,
#          258.34302],
#         [258.9714 , 258.9281 , 258.88977, ..., 259.14334, 259.08148,
#          259.02582],
#         [259.1285 , 259.0951 , 259.06787, ..., 259.22623, 259.19653,
#          259.15942],
#         ...,
#         [248.80576, 248.93936, 249.1113 , ..., 248.50146, 248.60413,
#          248.69072],
#         [249.4354 , 249.5022 , 249.57642, ..., 249.23994, 249.30428,
#          249.3822 ],
#         [250.06625, 250.10213, 250.138  , ..., 249.92401, 249.96977,
#          250.01678]]], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 1850-01-16T12:00:00 ... 2014-12-16T12:00:00
#   * lat      (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon      (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Attributes:
#     standard_name:  surface_temperature
#     long_name:      Surface Temperature
#     comment:        Temperature of the lower boundary of the atmosphere
#     units:          K
#     original_name:  GRTS
#     cell_methods:   area: time: mean
#     cell_measures:  area: areacella
#     history:        2018-11-30T16:15:08Z altered by CMOR: replaced missing va...

# %%
import matplotlib.gridspec as gridspec

cmap = mpl.cm.coolwarm


fig = plt.figure(figsize=(13,8))
gs = gridspec.GridSpec(nrows=2, ncols=2, height_ratios=[1, 2], hspace = 0.2)


ax0 = fig.add_subplot(gs[0, 0], projection=ccrs.PlateCarree())

ax0.set_title('Model 1\n')
ax0.set_global()
mm0 = ax0.pcolormesh(ts1.lon, ts1.lat, ts1.mean(axis = 0), \
                   transform=ccrs.PlateCarree(),cmap=cmap)  
ax0.coastlines()
ax0.gridlines(draw_labels=True)

cbar_ax0 = fig.add_axes([0.09, 0.6, 0.02, 0.30]) #[left, bottom, width, height]
cbar0 = fig.colorbar(mm0, cax=cbar_ax0, extend='both', orientation='vertical')
cbar0.set_label('Celsius')
cbar0.ax.tick_params(labelsize=8)
cbar_ax0.yaxis.tick_left()

ax1 = fig.add_subplot(gs[0, 1], projection=ccrs.PlateCarree())

ax1.set_title('Model 2\n')
ax1.set_global()
mm1 = ax1.pcolormesh(ts1.lon, ts1.lat, ts1.mean(axis = 0), \
                   transform=ccrs.PlateCarree(),cmap=cmap)  
ax1.coastlines()
ax1.gridlines(draw_labels=True)

cbar_ax1 = fig.add_axes([0.91, 0.6, 0.02, 0.30]) #[left, bottom, width, height]
cbar1 = fig.colorbar(mm1, cax=cbar_ax1, extend='both', orientation='vertical')
cbar1.set_label('Celsius')
cbar1.ax.tick_params(labelsize=8)


ax2 = fig.add_subplot(gs[1:, :], projection=ccrs.PlateCarree())
ax2.set_title("Model 3\n", y=-0.2)
ax2.set_global()
mm2 = ax2.pcolormesh(m5.lon, m5.lat, m5.mean(axis = 0), \
                   transform=ccrs.PlateCarree(),cmap=cmap )  
ax2.coastlines()
ax2.gridlines(draw_labels=True)

#- add colorbar
cbar_ax2 = fig.add_axes([0.85, 0.1, 0.02, 0.50]) #[left, bottom, width, height]
cbar2 = fig.colorbar(mm2, cax=cbar_ax2, extend='both', orientation='vertical')
cbar2.set_label('Celsius')
cbar2.ax.tick_params(labelsize=8)
plt.tight_layout()
plt.show()
# Out:
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/ipykernel_launcher.py:53: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# Bisogna capire come applicare le medie, secondo me vanno applicate nel quadrato, e nella dimensione che rimane in profondita è la serie storica. Portiamo prima tutti i modelli alla stessa griglia.

# %%
ts1_regridded = ts1.copy()

# %%
ts2_regridded = ts2.interp(lat=ts1.lat, lon=ts1.lon, method='linear')

# %%
ts3_regridded = m5.interp(lat=ts1.lat, lon=ts1.lon, method='linear')

# %% [markdown]
# ## METODO 1
#
# Calcolo delle medie sull'intero quadrato http://xarray.pydata.org/en/stable/examples/area_weighted_temperature.html

# %%
prova1 = ts1_regridded.groupby('time.year').mean('time')
prova1 = prova1.loc[prova1['year'] >= 1901]

prova2 = ts2_regridded.groupby('time.year').mean('time')
prova2 = prova2.loc[prova2['year'] >= 1901]

prova3 = ts3_regridded.groupby('time.year').mean('time')
prova3 = prova3.loc[prova3['year'] >= 1901]

# %%
prova1_ts = prova1.mean(("lon", "lat"))
prova2_ts = prova2.mean(("lon", "lat"))
prova3_ts = prova3.mean(("lon", "lat"))

# %%
ens_mean = np.nanmean([prova1_ts,prova2_ts,prova3_ts], axis=0)

# %%
plt.plot(prova1.year, ens_mean, color = "black", label = "Ensemble", ls = "-")
plt.plot(prova1.year, prova1_ts, label = "First time series", ls = "-")
plt.plot(prova1.year, prova2_ts, label = "Second time series", ls = "-")
plt.plot(prova1.year, prova3_ts, label = "Third time series", ls = "-")

plt.legend(bbox_to_anchor=(1.01, 0.6, 1.1, 0.2), loc='upper left')

# %%
ensemble_time = pd.concat([pd.Series(prova1.year, name = "time"), pd.Series(ens_mean, name = "Ensemble mean")], axis = 1, ignore_index = True)
ensemble_time.columns = ['time', 'ensemble mean']
ensemble_time
# Out:
#      time  ensemble mean
# 0    1901     278.824352
# 1    1902     278.761319
# 2    1903     278.530859
# 3    1904     278.556575
# 4    1905     278.529087
# ..    ...            ...
# 109  2010     279.755162
# 110  2011     279.652424
# 111  2012     279.868114
# 112  2013     279.982346
# 113  2014     279.938438
#
# [114 rows x 2 columns]

# %%
ensemble_ref = ensemble_time - ensemble_time.loc[(ensemble_time['time'] >= 1961) & (ensemble_time['time'] <= 1990)].mean()

# %%
ensemble_ref['time'] = ensemble_time['time']
ensemble_ref
# Out:
#      time  ensemble mean
# 0    1901      -0.234605
# 1    1902      -0.297639
# 2    1903      -0.528099
# 3    1904      -0.502382
# 4    1905      -0.529871
# ..    ...            ...
# 109  2010       0.696205
# 110  2011       0.593467
# 111  2012       0.809157
# 112  2013       0.923389
# 113  2014       0.879481
#
# [114 rows x 2 columns]

# %%
t, p = stats.ttest_ind(ensemble_ref['ensemble mean'], gmta_2['gmta'], equal_var = False)

plt.figure(figsize = (6,6))
p1, = plt.plot(ensemble_ref['time'], ensemble_ref['ensemble mean'], color = "black", label = "Ensemble", ls = "-")
p2, = plt.plot(ensemble_ref['time'], gmta_2['gmta'], color = "blue", label = "First time series", ls = "-")

extra = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
plt.legend([extra, p1, p2], ["p-value: {:.1}".format(p), "Multi-model ensemble", "HadCRUT4 model"],
           bbox_to_anchor=(1.01, 0.6, 1.1, 0.2), loc='upper left')
plt.grid()
