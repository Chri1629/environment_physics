# %% [markdown]
# # Esame Data Science - a.a. 2020/2021
#
# **Christian Uccheddu 800428**
#
# Di seguitono sono proposti gli esercizi per la prova d'esame.
# Per presentarsi all'esame è necessario aver implementato una soluzione per tutti e 3 gli esercizi.
#
# 1. [Esercizio Time Series](#esercizio1)
# 2. [Esercizio Deep Learning](#esercizio2)
# 3. [Esercizio Regressione Polinomiale](#esercizio3)
#
# > Le soluzioni sono basate sui codici presentati dal Prof. Biancini durante le esercitazioni

# %% [markdown]
# ## Importazione librerie
#
# Importo di seguito tutte le librerie con le relative versioni in modo che sia tutto riproducibile

# %%
import numpy as np
import pandas as pd
from scipy import stats
from scipy.spatial import distance
import scipy
from dateutil.parser import parse
import pmdarima as pm

import statsmodels
from scipy.stats import pearsonr
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller

from sklearn import datasets, linear_model
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, confusion_matrix

import datetime as dtm
from datetime import datetime

import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as tick
import seaborn as sns



import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.callbacks import EarlyStopping, History
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.activations import relu
from tensorflow.keras.layers import Dense, LeakyReLU, Dropout,AlphaDropout, Conv1D, Flatten, BatchNormalization, Input, GaussianNoise, ReLU
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import metrics
from tensorflow.keras import losses
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import *

pd.options.mode.chained_assignment = None

print("Pandas version:",pd.__version__)
print("Numpy version:",np.__version__)
print("Matplotlib version:",matplotlib.__version__)
print("Scipy version:",scipy.__version__)
print("Seaborn version:",sns.__version__)
print("Pmdarima version:",pm.__version__)
print("Statsmodels version:",statsmodels.__version__)
print("Tensorflow version:",tf.__version__)
# Out:
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Pandas version: 1.2.3
# Numpy version: 1.19.2
# Matplotlib version: 3.3.4
# Scipy version: 1.6.1
# Seaborn version: 0.11.1
# Pmdarima version: 1.8.0
# Statsmodels version: 0.12.2
# Tensorflow version: 1.14.0
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# <a id="esercizio1"></a>
# ## Esercizio TIme Series

# %% [markdown]
# Partiamo dai dati presi dal database Kaggle chiamato Hourly Energy Consumption. In esso sono contenuti dei dati, raccolti da PJM Interconnection, una società che coordina l'acquisto, la vendita e la consegna continua di elettricità all'ingrosso attraverso il mercato dell'energia dai fornitori ai clienti nella regione della Carolina del Sud, USA.
#
# Tutti i file .csv contengono righe con un timestamp e un valore. Il nome della colonna del valore corrisponde al nome del contraente. Il timestamp rappresenta una singola ora e il valore rappresenta l'energia totale, consumata durante quell'ora.
#
# https://www.kaggle.com/robikscube/hourly-energy-consumption

# %% [markdown]
# Leggendo il dataset `data/PJME_hourly.csv`, caricare i dati del consumo elettrico. Plottare la serie dati, analizarne le caratteristiche (tendenza e stagionalità) e provare a fare una regressione lineare del trend (per valutarne la tendenza).
#
# Infine provare a usare ARIMA per predire il consumo nei prossimi 240 periodi.

# %% [markdown]
# ### Esplorazione dei dati
#
# Per prima cosa importiamo i dati. Durante la fase di importazione ci accorgiamo di *tre problematiche*:
#
# - Nel cambio tra ora legale e ora solare l'orario riferito alle 03:00 è duplicato (in 4 casi). Per risolvere questa problematica leviamo quindi i valori duplicati sulle date ()
# - Nel cambio tra ora solare e ora legale non è presente l'osservazione riferita alle 03:00. Questo non inficia sui calcoli quindi decidiamo di non inserire questa osservazione.
# - Sono presenti delle inversioni cronologiche tra alcuni indici. Per questo motivo ordiniamo gli indici.

# %%
dati_in = pd.read_csv("data/PJME_hourly.csv", parse_dates=['Datetime'], index_col='Datetime')
dati = dati_in[~dati_in.index.duplicated(keep='first')].sort_index()

dati
# Out:
#                      PJME_MW
# Datetime
# 2002-01-01 01:00:00  30393.0
# 2002-01-01 02:00:00  29265.0
# 2002-01-01 03:00:00  28357.0
# 2002-01-01 04:00:00  27899.0
# 2002-01-01 05:00:00  28057.0
# ...                      ...
# 2018-08-02 20:00:00  44057.0
# 2018-08-02 21:00:00  43256.0
# 2018-08-02 22:00:00  41552.0
# 2018-08-02 23:00:00  38500.0
# 2018-08-03 00:00:00  35486.0
#
# [145362 rows x 1 columns]

# %% [markdown]
# Vediamo se la serie è stazionaria applicando il test ADFuller

# %%
result = adfuller(dati.values)

print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')

for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -19.884465
# p-value: 0.000000
# Critical Values:
# 	1%: -3.430
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# Osservando il valore della statistica e il p-value possiamo dire che la serie storica è stazionaria con un p-value decisamente significativo, questo vuol dire che probabilmente non andranno applicate ulteriori differenze nell'applicazione dei modelli ARIMA. Vediamo se ci sono tutte le date effettivamente presenti in quel periodo

# %%
print(f"Lunghezza dei dati inizali: {len(dati_in)}\nLunghezza dei dati dopo rimozione duplicati: {len(dati)}\nOsservazioni rimosse: {len(dati_in) - len(dati)}")
# Out:
# Lunghezza dei dati inizali: 145366
# Lunghezza dei dati dopo rimozione duplicati: 145362
# Osservazioni rimosse: 4

# %% [markdown]
# Guardiamo se ci sono valori mancanti nella serie storica. Qualora ci fossero potremmo riempirli in diversi modi, o utilizzando delle interpolazioni lineari o utilizzando degli algoritmi di Machine Learning per il riempimento di valori mancanti, in tal caso sono molto usati gli algoritmi di KNN.

# %%
dati.isnull().sum(axis = 0)
# Out:
# PJME_MW    0
# dtype: int64

# %% [markdown]
# Come notiamo non sono presenti osservazioni nulle. Procediamo quindi a visualizzare la serie storica, operazione molto utile in quanto possono emergere prime considerazioni

# %%
plt.figure(figsize=(16,6))
plt.plot(dati.index, dati.values, color = "#416685")
plt.xlabel("Date", fontsize = 15)
plt.ylabel("Value", fontsize = 15)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.title("Time Series", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Time Series')

# %% [markdown]
# Come possiamo notare ci sono delle evidenti stagionalità. Ci aspettiamo in anticipo che inserendo dei regressori trigonometrici all'interno dei modelli ARIMA si otterrano dei risultati buoni. Si vede inoltre che sono presenti delle alternanze tra picchi molto pronunciati e picchi meno pronunciati per i massimi. Per quanto riguarda i minimi essi sono sempre invece allo stesso livello.
# Passiamo quindi alla scomposizione della serie storica nelle sue componenti. In particolare utilizziamo sia la scomposizione additiva che quella moltiplicativa per vedere le differenze. Una volta scelta il tipo di scomposizione da utilizzare estrapoliamo il trend e proviamo a fare una semplice regressione lineare per studiarne l'andamento.

# %%
result_mul = seasonal_decompose(dati['PJME_MW'], model='multiplicative', extrapolate_trend='freq', period = 24*365)

fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(15,11))
plt.suptitle("Multiplicative decomposition", fontsize = 15, y = 0.92)

result_mul.observed.plot(ax=axes[0,0], legend=False, color = "#416685")
axes[0,0].set_ylabel('Observed')

result_mul.trend.plot(ax=axes[0,1], legend=False, color = "#416685")
axes[0,1].set_ylabel('Trend')

result_mul.seasonal.plot(ax=axes[1,0], legend=False, color = "#416685")
axes[1,0].set_ylabel('Seasonal')

result_mul.resid.plot(ax=axes[1,1], legend=False, style='o', color = "#416685")
axes[1,1].set_ylabel('Residual')
# Out:
# Text(0, 0.5, 'Residual')

# %% [markdown]
# Come notiamo sembra esserci una tendenza decrescente del trend, ovvero tende a diminuire nel tempo. Per quanto riguarda la stagionalità invece essa è chiaramente di tipo trigonometrico e sembra che possa essere ben approssimata da una sinusoide nell'arco di un anno.

# %%
result_add = seasonal_decompose(dati['PJME_MW'], model='additive', extrapolate_trend='freq', period = 24*365)

fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(15,11))
plt.suptitle("Additive decomposition", fontsize = 15, y = 0.92)

result_add.observed.plot(ax=axes[0,0], legend=False, color = "#416685")
axes[0,0].set_ylabel('Observed')

result_add.trend.plot(ax=axes[0,1], legend=False, color = "#416685")
axes[0,1].set_ylabel('Trend')

result_add.seasonal.plot(ax=axes[1,0], legend=False, color = "#416685")
axes[1,0].set_ylabel('Seasonal')

result_add.resid.plot(ax=axes[1,1], legend=False, style='o', color = "#416685")
axes[1,1].set_ylabel('Residual')
# Out:
# Text(0, 0.5, 'Residual')

# %% [markdown]
# In questo caso valgono tutte le considerazioni fatte per la decomposizione moltiplicativa. Come notiamo, infatti, le forme funzionali sono uguali tra le due decomposizioni. Decidiamo quindi di usare il trend della decomposizione additiva.
# Di seguito creiamo quindi la pandas Series che contiene gli indici di 240 osservazioni nel futuro in modo da poterlo utilizzare successivamente per disegnare le previsioni.

# %%
future_index = pd.DataFrame(
        {'Datetime': pd.date_range('2018-08-03 01:00:00', '2018-08-13 01:00:00', freq='1H', closed='left')}
     )
future_index.set_index('Datetime', inplace = True)

# %% [markdown]
# ### Regressione lineare trend
#
# Passiamo quindi alla regressione lineare sul tren ottenuto dalla decomposizione per via additiva della serie storica. Per prima cosa quindi estrapolo il trend dalla decomposizione. Una volta estratto il trend applichiamo quindi una regressione lineare per cercare di vedere se è un trend crescente o decrescente. Questa cosa può essere vista a partire dal coefficiente angolare della regressione; definendo la regressione lineare come:
#
# $$ \hat{y} = \beta_0 + \beta_1 x$$
#
# Si definiscono $\beta_0$ intercetta e $\beta_1$ coefficiente angolare. Se il valore di $\beta_1$ è minore di 0 allora il trend è decrescente, se è maggiore di 0 il trend è invece crescente.

# %%
trend = result_add.trend.values
time = np.linspace(0, trend.shape[0], trend.shape[0])

print(f"Trend shape: {trend.shape}\nTime shape: {time.shape}")
# Out:
# Trend shape: (145362,)
# Time shape: (145362,)

# %% [markdown]
# Ora che li abbiamo messi nel formato giusto applichiamo una regressione lineare al trend, osservandolo graficamente ci aspettiamo che venga una intercetta positiva con un coefficiente angolare negativo. Si nota infatti chiaramente come il trend sia decrescente. Creiamo quindi l'oggetto regressore lineare e fittiamolo alla serie storica, ricordiamoci di passarlo come numpy array in modo che sklearn riesca a lavorare più efficacemente.

# %%
reg = linear_model.LinearRegression()

reg.fit(time.reshape(-1,1), trend.reshape(-1,1))
# Out:
# LinearRegression()

# %% [markdown]
# Ora che abbiamo fittato il regressore estrapoliamo i coefficienti in modo da vedere come va il trend

# %%
coefficient = reg.coef_
intercept = reg.intercept_

print(f"Coefficients: {np.round(coefficient, 2)}\nIntercept: {np.round(intercept, 2)}")
# Out:
# Coefficients: [[-0.01]]
# Intercept: [32902.51]

# %% [markdown]
# Come notiamo il coefficiente angolare è negativo quindi vuol dire che il trend è leggermente decrescente. Disegniamo quindi il trend sovrapposto alla sua retta di regressione per vedere se ha senso. Vediamo inoltre come si comporta l'indice $r^2$ che descrive l'accordo con i dati.

# %%
predictions = reg.predict(time.reshape(-1,1))
r2 = r2_score(trend, predictions)

plt.figure(figsize=(16,6))
plt.plot(result_add.trend.index, result_add.trend.values, color = "#416685", label = "Trend")
plt.plot(dati.index, intercept + time*coefficient[0] , color = "#E88920", label = f"Linear regression on trend, r2: {round(r2,2)}")

plt.xticks(size = 12)
plt.yticks(size = 12)
plt.xlabel("Time", size = 15)
plt.ylabel("Trend", size = 15)
plt.title("Linear regression of the Trend", size = 15)
plt.grid()
plt.legend(fontsize=12, loc='upper right')

# %% [markdown]
# Come vediamo la regressione sembra adattarsi bene ai dati, ovviamente l'indice $r^2$ non è altissimo; ciò è presto detto infatti la forma funzionale del trend e la retta sono completamente diverse ma come si vede il trend è decrescente esattamente come la retta di regressione lineare.

# %% [markdown]
# ### AUTO ARIMA
#
# Passiamo quindi alla creazione dei modelli ARIMA, per prima cosa proviamo un modello dato dalla funzione autoarima. Questa funzione consente di operare una grid search all'internod dei parametri p,d,q da passare al modello ARIMA. Successivamente verrà tenuto solo il modello migliore su cui verranno effettuate le predizioni 240 osservazioni in avanti calcolandone anche l'intervallo di confidenza. Controlliamo prima i grafici di ACF e PACF della serie storica originale, di quella differenziata una volta e di quella differenziata due volte per cercare il modello ARIMA migliore.

# %%
fig, axes = plt.subplots(2, 3, sharex=True, figsize = (18,8))

plot_acf(dati.dropna(),  lags=100, ax=axes[0,0])
plot_acf(dati.diff().dropna(), lags=100, ax=axes[0,1])
plot_acf(dati.diff().diff().dropna(), lags=100, ax=axes[0,2])

plot_pacf(dati.dropna(),  lags=100, ax=axes[1,0])
plot_pacf(dati.diff().dropna(), lags=100, ax=axes[1,1])
plot_pacf(dati.diff().diff().dropna(), lags=100, ax=axes[1,2])

plt.show()

# %% [markdown]
# Guardando i grafici sopra possiamo dedurre che probabilmente il modello giusto sarà il modello (2,0,1)(2,1,1)\[24\] che dovrebbe consentire di fare entrare tutti i lag all'interno delle bande. Non si riesce tuttavia a fittare questo modello perché è computazionalmente troppo dispendioso su così tante osservazioni. Cerchiamo quindi di fittare un modello simile che consenta di avere performance equiparabili.

# %%
smodel = pm.auto_arima(dati, start_p = 1, start_q = 1, max_p = 3, max_q = 3,
                       start_P = 0, start_Q = 0, max_P = 2, max_Q = 2,  d = 1, D = 0,
                       max_order = None, seasonal = False, m = 0,
                       test='adf', trace = True, error_action='ignore',  
                       suppress_warnings = True, 
                       stepwise = True)

smodel.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2320845.838, Time=30.61 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2529215.296, Time=2.61 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2357815.473, Time=7.12 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2393936.225, Time=27.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2529213.296, Time=1.45 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2318819.918, Time=18.15 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2322478.998, Time=10.06 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=2318487.242, Time=28.91 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=2320950.982, Time=14.58 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=2299347.113, Time=143.86 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2299705.230, Time=122.80 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=2288676.430, Time=175.33 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=2298856.450, Time=117.16 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=2288672.291, Time=72.03 sec
#  ARIMA(2,1,3)(0,0,0)[0]             : AIC=2298854.455, Time=39.78 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : AIC=2299295.761, Time=59.53 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=2299702.174, Time=44.50 sec
#
# Best model:  ARIMA(3,1,3)(0,0,0)[0]
# Total fit time: 915.643 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:               145362
# Model:               SARIMAX(3, 1, 3)   Log Likelihood            -1144329.145
# Date:                Sat, 08 May 2021   AIC                        2288672.291
# Time:                        13:22:42   BIC                        2288741.499
# Sample:                             0   HQIC                       2288692.947
#                              - 145362
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          2.4426      0.002   1050.874      0.000       2.438       2.447
# ar.L2         -2.0019      0.004   -448.629      0.000      -2.011      -1.993
# ar.L3          0.5291      0.002    224.928      0.000       0.524       0.534
# ma.L1         -1.3787      0.002   -599.762      0.000      -1.383      -1.374
# ma.L2         -0.0926      0.004    -26.252      0.000      -0.099      -0.086
# ma.L3          0.5106      0.002    296.189      0.000       0.507       0.514
# sigma2      4.019e+05    997.710    402.843      0.000       4e+05    4.04e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  85.92   Jarque-Bera (JB):            115212.50
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.70   Skew:                            -0.10
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# Come possiamo notare dall'output il modello migliore che viene scelto è il modello ARIMA(3, 1, 3). Si potrebbe migliorare di molto questo modello inserendo dei regressori esterni ma si fa tropo fatica con i tempi di computazione quindi non verà fatto.

# %%
n_periods = 240
fitted, confint = smodel.predict(n_periods = n_periods, return_conf_int = True)
index_of_fc = pd.date_range(dati.index[-1], periods = n_periods, freq = 'MS')


fitted_series = pd.Series(fitted, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)


plt.figure(figsize=(16, 7))

plt.plot(dati.index, dati.values, color = "#416685")

plt.plot(future_index.index, fitted_series, color='darkgreen')

plt.fill_between(future_index.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.xlabel("Date", fontsize = 15)
plt.ylabel("Value", fontsize = 15)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlim(dati.index[-240], future_index.index[-1]) 

plt.title("ARIMA - Final Forecast of 240 observations (10 days)", fontsize = 15)
plt.show()

# %% [markdown]
# Come possiamo notare soprattutto per le prime osservazioni il modello sembra essere in accordo con le osservazioni precedenti. Come è noto dalla letteratura infatti le predizioni sulla domanda dell'energia elettrica si fanno con un orizzonte temporale medio-breve. Questo modello dovrebbe essere molto migliorabile inserendo regressori esterni quali sinusoidi e regerssori per i week-end. Tuttavia questi modelli sono troppo pesanti computazionalmente su un così gran numero di dati e quindi non verranno provati.
# Un altro approccio potrebbe essere quello di separare la serie storica in 24 serie storiche, una per ogni ora e poi fare le predizioni su ogni modello. Questo approccio è stato descritto notevolmente in letteratura e lo applicheremo nella sotto-sezione successiva.

# %% [markdown]
# ### 24 SERIE STORICHE
#
# Come detto prima creiamo dunque 24 serie storiche una per ogni ora del giorno, successivamente applicheremo il metodo AUTO ARIMA alle 24 serie storiche in modo che le predizioni vengano fatte su 10 osservazioni alla volta.

# %%
serie_orarie = {}
for ora in range(24):
    serie_orarie["orario_{0}".format(ora)] = dati[dati.index.hour == ora]

# %% [markdown]
# Mostriamo di seguito le 24 serie storiche per vedere se ci sono marcate differenze tra i diversi orari.

# %%
plt.figure(figsize = (25,15))

for ora in range(24):
    plt.subplot(4, 6, ora + 1)
    plt.plot(serie_orarie["orario_{0}".format(ora)].index, serie_orarie["orario_{0}".format(ora)].values, color = "#416685")
    plt.xlabel("", fontsize = 10)
    plt.ylabel("", fontsize = 10)
    plt.xticks(fontsize = 8)
    plt.yticks(fontsize = 8)
    plt.title("Ora {}".format(ora), fontsize = 10)

# %% [markdown]
# Come notiamo non sembrano esserci differenze nelle forme funzionali tra le varie ore. Applichiamo quindi i mdoelli AUTO ARIMA alle 24 serie storiche salvando tutti i modelli in un dizionario in modo da poterli richiamare con facilità.

# %%
smodels = {}
for ora in range(24):
    smodels["orario_{0}".format(ora)] = pm.auto_arima(serie_orarie["orario_{0}".format(ora)], start_p = 1, start_q = 1, max_p = 2, max_q = 2,
                               start_P = 0, start_Q = 0, max_P = 2, max_Q = 2,  d = 1, D = 0,
                               max_order = 3, seasonal = False, m = 0,
                               test='adf', trace = True, error_action='ignore',  
                               suppress_warnings = True, 
                               stepwise = True)
    print(f"Finita ora {ora}")
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC
sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=114809.234, Time=0.87 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 10.747 seconds
# Finita ora 19
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=114320.719, Time=0.75 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=114550.321, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=114487.128, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=114424.831, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=114548.323, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=113274.711, Time=0.79 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=113980.072, Time=0.45 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=113250.621, Time=1.91 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=113328.382, Time=1.03 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=113248.654, Time=1.29 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=113326.422, Time=0.63 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=113272.743, Time=0.59 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=114318.719, Time=0.51 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 8.686 seconds
# Finita ora 20
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=113409.605, Time=0.48 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=113707.196, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=113611.485, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=113515.976, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=113705.198, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=112342.862, Time=0.91 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=113048.604, Time=0.47 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=112315.933, Time=1.43 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=112402.566, Time=1.11 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=112313.969, Time=0.96 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=112400.609, Time=0.64 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=112340.896, Time=0.62 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=113407.605, Time=0.34 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 7.700 seconds
# Finita ora 21
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=112423.394, Time=0.69 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=112691.603, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=112608.906, Time=0.27 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=112528.189, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=112689.604, Time=0.07 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=111434.055, Time=0.85 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=112076.612, Time=0.43 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=111410.743, Time=1.57 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=111480.386, Time=0.97 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=111408.779, Time=0.91 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=111478.428, Time=0.56 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=111432.089, Time=0.56 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=112421.394, Time=0.44 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 7.718 seconds
# Finita ora 22
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=110945.784, Time=1.13 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=111154.131, Time=0.11 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=111101.131, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=111049.772, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=111152.132, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=110076.903, Time=2.10 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=110621.923, Time=0.47 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=110069.093, Time=1.31 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=110103.013, Time=0.97 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=110067.128, Time=0.84 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=110101.052, Time=0.55 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=110074.932, Time=1.21 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=110943.784, Time=0.63 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0]
# Total fit time: 9.926 seconds
# Finita ora 23

# %% [markdown]
# Creiamo ora i dizionari delle predizioni che contengono anche gli intervalli di confidenza. In questo modo tutti i risultati saranno facilmente concatenabili per poterli visualizzare

# %%
import datetime

n_periods = 10
previsioni_orarie = {}
index_of_fc = {}
fitted_series = {}
lower_series = {}
upper_series = {}

for ora in range(24):
    previsioni_orarie["prev_orario_{0}".format(ora)],  previsioni_orarie["conf_orario_{0}".format(ora)] = smodels["orario_{0}".format(ora)].predict(n_periods = n_periods, return_conf_int = True)
    index_of_fc["prev_orario_{0}".format(ora)] = pd.date_range(serie_orarie["orario_{0}".format(ora)].index[-1] + datetime.timedelta(days=1), periods = n_periods, freq = 'D') 
    fitted_series["prev_orario_{0}".format(ora)] = pd.Series(previsioni_orarie["prev_orario_{0}".format(ora)], index = index_of_fc["prev_orario_{0}".format(ora)])
    lower_series["prev_orario_{0}".format(ora)] = pd.Series(previsioni_orarie["conf_orario_{0}".format(ora)][:, 0], index = index_of_fc["prev_orario_{0}".format(ora)])
    upper_series["prev_orario_{0}".format(ora)] = pd.Series(previsioni_orarie["conf_orario_{0}".format(ora)][:, 1], index = index_of_fc["prev_orario_{0}".format(ora)])

# %% [markdown]
# Concateniamo i risultati per orario e ordiniamoli, probabilmente questo non è il metodo più efficiente per farlo ma funziona bene.

# %%
previsioni = pd.concat([fitted_series['prev_orario_0'], fitted_series['prev_orario_1'], fitted_series['prev_orario_2'], fitted_series['prev_orario_3'], 
                        fitted_series['prev_orario_4'], fitted_series['prev_orario_5'], fitted_series['prev_orario_6'], fitted_series['prev_orario_7'], 
                        fitted_series['prev_orario_8'], fitted_series['prev_orario_9'], fitted_series['prev_orario_10'], fitted_series['prev_orario_11'], 
                        fitted_series['prev_orario_12'], fitted_series['prev_orario_13'], fitted_series['prev_orario_14'], fitted_series['prev_orario_15'], 
                        fitted_series['prev_orario_16'], fitted_series['prev_orario_17'], fitted_series['prev_orario_18'], fitted_series['prev_orario_19'], 
                        fitted_series['prev_orario_20'], fitted_series['prev_orario_21'], fitted_series['prev_orario_22'], fitted_series['prev_orario_23']], 
                       axis = 0).sort_index()

previsioni_inf = pd.concat([lower_series['prev_orario_0'], lower_series['prev_orario_1'], lower_series['prev_orario_2'], lower_series['prev_orario_3'], 
                        lower_series['prev_orario_4'], lower_series['prev_orario_5'], lower_series['prev_orario_6'], lower_series['prev_orario_7'], 
                        lower_series['prev_orario_8'], lower_series['prev_orario_9'], lower_series['prev_orario_10'], lower_series['prev_orario_11'], 
                        lower_series['prev_orario_12'], lower_series['prev_orario_13'], lower_series['prev_orario_14'], lower_series['prev_orario_15'], 
                        lower_series['prev_orario_16'], lower_series['prev_orario_17'], lower_series['prev_orario_18'], lower_series['prev_orario_19'], 
                        lower_series['prev_orario_20'], lower_series['prev_orario_21'], lower_series['prev_orario_22'], lower_series['prev_orario_23']], 
                       axis = 0).sort_index()


previsioni_up = pd.concat([upper_series['prev_orario_0'], upper_series['prev_orario_1'], upper_series['prev_orario_2'], upper_series['prev_orario_3'], 
                        upper_series['prev_orario_4'], upper_series['prev_orario_5'], upper_series['prev_orario_6'], upper_series['prev_orario_7'], 
                        upper_series['prev_orario_8'], upper_series['prev_orario_9'], upper_series['prev_orario_10'], upper_series['prev_orario_11'], 
                        upper_series['prev_orario_12'], upper_series['prev_orario_13'], upper_series['prev_orario_14'], upper_series['prev_orario_15'], 
                        upper_series['prev_orario_16'], upper_series['prev_orario_17'], upper_series['prev_orario_18'], upper_series['prev_orario_19'], 
                        upper_series['prev_orario_20'], upper_series['prev_orario_21'], upper_series['prev_orario_22'], upper_series['prev_orario_23']], 
                       axis = 0).sort_index()

# %% [markdown]
# Disegniamo ora le predizioni fatte sulle 24 serie storiche

# %%
plt.figure(figsize=(16, 7))

plt.plot(dati.index, dati.values, color = "#416685")

plt.plot(previsioni.index, previsioni.values, color='darkgreen')


plt.fill_between(previsioni.index, 
                 previsioni_inf, 
                 previsioni_up, 
                 color='k', alpha=.15)


plt.xlabel("Date", fontsize = 15)
plt.ylabel("Value", fontsize = 15)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xlim(dati.index[-240], previsioni.index[-1]) 

plt.title("ARIMA - Final Forecast of 240 observations (10 days)", fontsize = 15)
plt.show()

# %% [markdown]
# Come vediamo in questo caso le predizioni sono decisamente migliori di quelle precedenti, in particolare vediamo che non si appiattisce più dopo poche osservazioni. Questo è dato dal fatto che ora le predizioni non vengono più fatte tutte insieme ma vengono fatte 24 volte 10 previsioni aumentando quindi la bontà dei risultati. Possiamo quindi affermare con certezza che questo modello sia migliore di quello che considera tutta la serie storica contemporaneamente.

# %% [markdown]
# <a id="esercizio2"></a>
# ## Esercizio Deep Learning

# %% [markdown]
# Creare una rete neurale Deep Learning per predire se un paziende ha una malattia cardiaca o no. Utilizziamo i dati presenti nel dataset linkato qui: https://archive.ics.uci.edu/ml/datasets/Heart+Disease
#
# E disponibile nel file `data/heart.csv`, esploriamo il dataset e proviamo a creare una rete come descritto con Tensorflow.

# %% [markdown]
# ### Esplorazione variabili
#
# Iniziamo quindi con l'importare il dataset e vedere le variabili da cui è composto

# %%
dati = pd.read_csv("data/heart.csv")
dati
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# Controlliamo le prime statistiche descrittive, facciamolo ovviamente solo sulle variabili continue

# %%
cont_var = ['age', 'trestbps', 'chol',  'thalach', 'oldpeak']
dati[cont_var].describe()
# Out:
#               age    trestbps        chol     thalach     oldpeak
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337  131.623762  246.264026  149.646865    1.039604
# std      9.082101   17.538143   51.830751   22.905161    1.161075
# min     29.000000   94.000000  126.000000   71.000000    0.000000
# 25%     47.500000  120.000000  211.000000  133.500000    0.000000
# 50%     55.000000  130.000000  240.000000  153.000000    0.800000
# 75%     61.000000  140.000000  274.500000  166.000000    1.600000
# max     77.000000  200.000000  564.000000  202.000000    6.200000

# %% [markdown]
# Controlliamo per sicurezza se sono presenti valori nulli.

# %%
dati.isnull().sum(axis = 0)
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Come possiamo vedere non sono presenti valori nulli all'interno delle colonne, ciò vuol dire che non dobbiamo occuparci di sostituirli. Possiamo dedicarci ora alla produzione di qualche grafico di esplorazione delle variabili. Per prima cosa guardiamo se si tratta di un problema di classificazione sbilanciati

# %%
class_0, class_1 = np.bincount(dati['target'])
total = class_0 + class_1
print('Total: {}\nClasse 1: {} ({:.2f}% del totale)\nClasse 0: {} ({:.2f}% del totale)\n'.format(total, 
                                                                                             class_1, 100 * class_1 / total, 
                                                                                             class_0, 100 * class_0 / total))
# Out:
# Total: 303
# Classe 1: 165 (54.46% del totale)
# Classe 0: 138 (45.54% del totale)

# %% [markdown]
# Come vediamo il problema è bilanciato nella classe di target, ciò vuol dire che non sono necessarie ulteriori operazioni. Iniziamo a vedere come si distribuiscono le variabili continue, per farlo useremo un plot che ci consente di divedere le distribuzioni per sesso applicando una funzione di densità di probabilità.

# %%
def violin(dati, colonna):
    fig, ax = plt.subplots(figsize=(8, 6))

    sns.kdeplot(dati.loc[dati["sex"] == 0][colonna], color='blue', ax=ax)

    x = ax.lines[-1].get_xdata()
    y = ax.lines[-1].get_ydata()

    for p in ax.patches:  
        p.set_height(-p.get_height())
    for l in ax.lines:  
        l.set_ydata(-l.get_ydata())

    ax.fill_between(x, 0, -y, color='blue', alpha=0.3)

    sns.kdeplot(dati.loc[dati["sex"] == 1][colonna], shade = True, color = "violet")

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

    pos_ticks = np.array([t for t in ax.get_yticks() if t > 0])
    ticks = np.concatenate([-pos_ticks[::-1], [0], pos_ticks])

    ax.set_yticks(ticks)
    ax.set_yticklabels([f'{abs(t):.2f}' for t in ticks])
    ax.spines['bottom'].set_position('zero')
    plt.legend([],[], frameon=False)

    plt.xlabel(r"Value", horizontalalignment = "right", x=1.0, size = 15)
    plt.yticks(size = 12)
    plt.legend([],[], frameon=False)
    plt.ylabel("Density of probability", fontsize = 15)
    plt.title("{}".format(colonna), fontsize = 20)

# %% [markdown]
# Applichiamo quindi la funzione creata alle variabili continue presenti all'interno del dataset

# %%
for variabile in cont_var: 
    violin(dati, variabile)

# %% [markdown]
# Come si può notare non sono presenti differenze tra le distribuzioni delle variabili per sesso. Guardiamo anche un pairplot per vedere come sono le relazioni tra le variabili.

# %%
sns.pairplot(dati[cont_var], corner= True, palette = "#416685", diag_kind="kde")

# %% [markdown]
# Per vedere meglio queste correlazioni è più utile produrre una matrice di correlazione. Creiamo quindi una correlation matrix che ci permetta di visualizzare i coefficienti di correlazione tra le variabili. In particolare decidiamo di mostrare solo le correlazioni che presentano un p-value < 0.05.

# %%
def calculate_pvalues(df):
    df = df.dropna()._get_numeric_data()
    dfcols = pd.DataFrame(columns=df.columns)
    pvalues = dfcols.transpose().join(dfcols, how='outer')
    for r in df.columns:
        for c in df.columns:
            pvalues[r][c] = round(pearsonr(df[r], df[c])[1], 4)
    return pvalues

def plot_cor_matrix(corr, mask=None):
    f, ax = plt.subplots(figsize=(10, 10))
    sns.heatmap(corr, ax=ax,
                mask=mask,
                # cosmetics
                annot=True, vmin=-1, vmax=1, center=0,
                cmap='coolwarm', linewidths=0, linecolor='black', cbar_kws={'orientation': 'vertical'})
    plt.xticks(size = 15)
    plt.yticks(size = 15, rotation = 0)

# %%
corr = dati.corr()      
p_values = calculate_pvalues(dati)
mask = np.invert(np.tril(p_values<0.05))
plot_cor_matrix(corr,mask)

# %% [markdown]
# Come vediamo ci sono un bel po' di correlazioni tra le variabili. Ciò ci suggerische potremmo fare a meno di alcune variabili per questo problema di classificazione. Si potrebbe pensare quindi di applicare tecniche di dimensionality reduction quali la PCA o la UMAP (che a differenza della PCA è un metodo non lineare) ma non è lo scopo di questo lavoro. Passiamo ora alle visualizzazioni per quanto riguarda le variabili categoriche tramite l'uso di grafici a barre

# %%
cat_var = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']

fig = plt.figure(figsize = (15,8))

for i,colonna in enumerate(cat_var):
    plt.subplot(2,4,i+1)
    sns.countplot(y = colonna, data = dati, palette = "rainbow")

# %% [markdown]
# Come vediamo non tutte le classi sono bilanciate. Per quanto riguarda il sesso si può notare come quelli che presentano un valore di "sex" uguale ad 1 sono circa il doppio a quelli che lo presentano uguale a 0. Anche tutte le altre classi non sono completamente proporzionate ma non avendo conoscenza di dominio non si può dire nulla a riguardo.

# %% [markdown]
# ### Preprocessing
#
# In questa fase dobbiamo occuparci del preprocessing delle variabili, quindi dobbiamo scalare le variabili continue e rendere categoriche le variabili categoriche. Dobbiamo inoltre dividere in train e validation le variabili in modo da poter addestrare il modello e successivamente valutarne le performance. Creiamo per prima cosa la funzione che permette di effettuare le operazioni di preprocessing dei dati. In particolare la funzione preprocess data consente di definire scalare le variabili continue e di categorizzare le variabili categoriche in modo che siano utilizzabili da tensorflow.

# %%
def preprocess_data(df, cont_var, cat_var):
    
    ct = ColumnTransformer([
            ('continuos', StandardScaler(), cont_var),
            ('categorical', OneHotEncoder(), cat_var)],
            remainder='passthrough')

    df = ct.fit_transform(df)

    return df

# %% [markdown]
# Applichiamo questa funzione al dataset in modo da scalare le variabili

# %%
cont_var = ['age', 'trestbps', 'chol',  'thalach', 'oldpeak']
cat_var = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']

dati_scaled = preprocess_data(dati, cont_var, cat_var)

print("Le dimensioni del dataset dopo le operazioni di preprocessing sono:", dati_scaled.shape)
# Out:
# Le dimensioni del dataset dopo le operazioni di preprocessing sono: (303, 31)

# %% [markdown]
# Dividiamo quindi in train e validation il dataset. Per farlo settiamo un seed in modo che i risultati siano riproducibili. Decidiamo inoltre che la proporzione sarà 80\% / 20\% a causa della mancanza di altri dati. Questa proporzione ci consente infatti di avere diversi dati su cui addestrare il modello ma di averne abbastanza su cui testare.
# Trasformiamo inoltre in numpy array in modo da poter passare i vettori a keras senza che nascano warning di alcun tipo.

# %%
x_train, x_val, y_train, y_val = train_test_split(dati_scaled[:, :-1], dati_scaled[:, -1], test_size = 0.2, random_state = 42)
x_train = np.array(x_train)
x_val = np.array(x_val)

y_train = tf.keras.utils.to_categorical(y_train, num_classes = 2)
y_val = tf.keras.utils.to_categorical(y_val, num_classes = 2)

print(f"x train shape: {x_train.shape}\ny train shape: {y_train.shape}\nx val shape: {x_val.shape}\ny val shape: {y_val.shape}")
# Out:
# x train shape: (242, 30)
# y train shape: (242, 2)
# x val shape: (61, 30)
# y val shape: (61, 2)

# %% [markdown]
# Come vediamo tutti i vettori sono stati trasformati nel modo corretto, sia dal punto di vista della numerosità che dal punto di vista delle colonne. Il numero di colonne è infatti aumentato a causa delle trasformazion che abbiamo applicato alle variabili categoriche. Ricordiamo inoltre che abbiamo trasformato anche la variabile di target in un oggetto **categorical** di keras poiché keras lavora meglio con questo tipo di variabili.

# %% [markdown]
# ### Rete neurale
#
# Definiamo quindi la rete neurale. Visto che sono presenti pochi dati cerchiamo di costruire una rete con pochi parametri. Avendo un problema di classificazione binaria utilizziamo la **binary_crossentropy** come loss function e la funzione di attivazione softmax sull'ultimo layer in modo da migliorare le predizioni. Aggiungiamo inoltre dei layer di Batch Normalization per aiutare a non avere dell'overfitting. Lasciamo di seguito solo il modello che ha funzionato meglio dopo diversi tentativi per non appesantire troppo il notebook.

# %%
model = Sequential()
model.add(Input(shape = x_train.shape[1]))
model.add(Dense(16, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dense(8, activation = 'softmax'))
model.add(BatchNormalization())
model.add(Dense(2))

model.compile(loss = losses.binary_crossentropy,
            optimizer = 'adam',
            metrics = ['acc'])

print(model.summary())
# Out:
# WARNING:tensorflow:From /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                496
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16)                64
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 136
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8)                 32
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 18
# =================================================================
# Total params: 746
# Trainable params: 698
# Non-trainable params: 48
# _________________________________________________________________
# None

# %% [markdown]
# Definiamo a parte gli iperparametri del modello; in particolare:
#
# - min_delta: definisce l'intervallo di cui deve diminuire la loss function nel numero di *p_epochs* per attivare la funzione early stopping.
# - p_epochs: definisce il numero di epochs in cui la funzione di loss non deve diminuire di min_delta per attivare la funzione di early stopping.
# - n_epochs: il numero di epoche da far fare al classificatore
# - batch: la batch size del modello
# - learning_rate: il learning rate del modello
#
# Tutti questi parametri sono stati settati empiricamente.

# %%
min_delta = 0.01
p_epochs = 50
n_epochs = 300
batch = 128
learning_rate = 0.003

# %% [markdown]
# Definiamo quindi un callback di early stopping per fermare il modello nel momento in cui la loss function sul validation set non sta più scendendo. Potevano essere utilizzati diversi callback diversi ma sarebbero stati inutili nel nostro caso.

# %%
early_stop = EarlyStopping(monitor='val_loss', min_delta = min_delta,
                        patience = p_epochs, verbose = 0)

# %% [markdown]
# Fittiamo quindi il modello sui dati di train in modo da poter successivamente fare le predizioni.

# %%
history = model.fit(x_train, y_train,
                    validation_data = (x_val, y_val),
                    epochs = n_epochs, initial_epoch = 0,
                    batch_size = batch, shuffle = True,
                    callbacks=[early_stop])
# Out:
# Train on 242 samples, validate on 61 samples
# WARNING:tensorflow:From /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/300
# 242/242 [==============================] - 0s 1ms/sample - loss: 7.1578 - acc: 0.4215 - val_loss: 6.8865 - val_acc: 0.5000
# Epoch 2/300
# 242/242 [==============================] - 0s 42us/sample - loss: 6.7948 - acc: 0.4215 - val_loss: 6.6285 - val_acc: 0.5000
# Epoch 3/300
# 242/242 [==============================] - 0s 27us/sample - loss: 6.8526 - acc: 0.4360 - val_loss: 6.5831 - val_acc: 0.5000
# Epoch 4/300
# 242/242 [==============================] - 0s 27us/sample - loss: 6.6991 - acc: 0.4421 - val_loss: 6.5678 - val_acc: 0.5000
300
# 242/242 [==============================] - 0s 29us/sample - loss: 1.6699 - acc: 0.8161 - val_loss: 1.7196 - val_acc: 0.7377
# Epoch 204/300
# 242/242 [==============================] - 0s 27us/sample - loss: 1.6113 - acc: 0.8182 - val_loss: 1.7334 - val_acc: 0.7377
# Epoch 205/300
# 242/242 [==============================] - 0s 31us/sample - loss: 1.7527 - acc: 0.8182 - val_loss: 1.8054 - val_acc: 0.7377
# Epoch 206/300
# 242/242 [==============================] - 0s 28us/sample - loss: 1.6087 - acc: 0.8182 - val_loss: 1.7979 - val_acc: 0.7377
# Epoch 207/300
# 242/242 [==============================] - 0s 29us/sample - loss: 1.6895 - acc: 0.8079 - val_loss: 1.7908 - val_acc: 0.7377
# Epoch 208/300
# 242/242 [==============================] - 0s 29us/sample - loss: 1.6077 - acc: 0.8285 - val_loss: 1.7859 - val_acc: 0.7377
# Epoch 209/300
# 242/242 [==============================] - 0s 27us/sample - loss: 1.5526 - acc: 0.8244 - val_loss: 1.7820 - val_acc: 0.7377
# Epoch 210/300
# 242/242 [==============================] - 0s 29us/sample - loss: 1.6044 - acc: 0.8099 - val_loss: 1.7789 - val_acc: 0.7377
# Epoch 211/300
# 242/242 [==============================] - 0s 29us/sample - loss: 1.4604 - acc: 0.8079 - val_loss: 1.6913 - val_acc: 0.7459
# Epoch 212/300
# 242/242 [==============================] - 0s 26us/sample - loss: 1.4883 - acc: 0.8140 - val_loss: 1.6814 - val_acc: 0.7459
# Epoch 213/300
# 242/242 [==============================] - 0s 27us/sample - loss: 1.4550 - acc: 0.8244 - val_loss: 1.6756 - val_acc: 0.7377
# Epoch 214/300
# 242/242 [==============================] - 0s 32us/sample - loss: 1.4715 - acc: 0.8264 - val_loss: 1.6712 - val_acc: 0.7377
# Epoch 215/300
# 242/242 [==============================] - 0s 28us/sample - loss: 1.5736 - acc: 0.8037 - val_loss: 1.6677 - val_acc: 0.7377
# Epoch 216/300
# 242/242 [==============================] - 0s 26us/sample - loss: 1.5196 - acc: 0.8161 - val_loss: 1.6648 - val_acc: 0.7377
# Epoch 217/300
# 242/242 [==============================] - 0s 30us/sample - loss: 1.5465 - acc: 0.8285 - val_loss: 1.6658 - val_acc: 0.7377
# Epoch 218/300
# 242/242 [==============================] - 0s 26us/sample - loss: 1.4713 - acc: 0.8182 - val_loss: 1.6706 - val_acc: 0.7459
# Epoch 219/300
# 242/242 [==============================] - 0s 30us/sample - loss: 1.5454 - acc: 0.8161 - val_loss: 1.6762 - val_acc: 0.7459
# Epoch 220/300
# 242/242 [==============================] - 0s 28us/sample - loss: 1.5010 - acc: 0.8202 - val_loss: 1.6816 - val_acc: 0.7459
# Epoch 221/300
# 242/242 [==============================] - 0s 28us/sample - loss: 1.5004 - acc: 0.8058 - val_loss: 1.6875 - val_acc: 0.7459
# Epoch 222/300
# 242/242 [==============================] - 0s 28us/sample - loss: 1.4426 - acc: 0.8285 - val_loss: 1.6945 - val_acc: 0.7541

# %% [markdown]
# Come notiamo si è attivata la funzione di early stopping che ci ha aiutato a prevenire l'overfitting. Facciamo predire al classificatore i valori in modo da poterli utilizzare per confrontare con i valori veri. Ricordiamo che l'output del nostro modello sarà un vettore di due entrate per ogni record, la prima entrata è uguale al valore della funzione softmax per la classe 0 mentre la seconda entrata è uguale al valore della funzione softmax per la classe 1. Scegliamo quindi di assegnare a quella osservazione la classe che ottiene il valore di softmax più alto.

# %%
pred = model.predict(x_val)
pred = np.argmax(pred, axis=1)

# %% [markdown]
# ### Risultati

# %% [markdown]
# Definiamo di seguito la funzione che permette di mostrare la loss function e l'accuratezza ottenuta dal modello in fase di addestramento sia sull'insieme di train che sull'insieme di validation. Questo grafico è molto utile in quanto ci permette di vedere se si sta presentando over fitting ed eventualmente correggere il modello.

# %%
def acc_loss(history):
    fig = plt.figure(figsize=(14,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['loss'], label = "Train", color = "#416685")
    plt.plot(history.history['val_loss'], label="Validation", color = "#E88920")
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.xlabel('Epochs', size = 15)
    plt.ylabel('Loss', size = 15) 
    
    plt.subplot(1,2,2)
    plt.plot(history.history['acc'], label = "Train", color = "#416685")
    plt.plot(history.history['val_acc'], label="Validation", color = "#E88920")
    plt.legend(fontsize=12, bbox_to_anchor=(1.01, 0.6, 1.1, 0.2), loc='upper left')
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.xlabel('Epochs', size = 15)
    plt.ylabel('Accuracy', size = 15)

# %%
acc_loss(history)

# %% [markdown]
# Come possiamo notare dai grafici relativi alla loss e alla accuracy non è presente tantissimo overfitting. La curva per il validation set infatti sta poco staccata da quella del training set lasciando supporre che avvenga un effettivo apprendimento. Proponiamo di seguito il classification report relativo a questo problema di classificazione per vedere i risultati.

# %%
report = classification_report(np.argmax(y_val, axis=1), pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.93      0.82        29
#            1       0.92      0.69      0.79        32
#
#     accuracy                           0.80        61
#    macro avg       0.82      0.81      0.80        61
# weighted avg       0.83      0.80      0.80        61

# %% [markdown]
# Come possiamo notare tutte le metriche sono molto buone. Per essere sicuri che il classificatore non stia sparando una sola classe (dovremmo già esserne sicuri quando la precision e la recall delle due classi) proponiamo la matrice di confusione calcolata sui valori del validation set.

# %%
cm = confusion_matrix(np.argmax(y_val, axis=1), pred)

fig = plt.figure(figsize = (6,6))
ax = plt.subplot()
sns.heatmap(cm, annot=True, annot_kws={"size": 16},
           linewidths=.1, cmap="YlGnBu")
plt.xlabel("True Class", size = 15)
plt.ylabel("Predicted Class", size = 15)
plt.xticks(size = 12)
plt.yticks(size = 12)
ax.yaxis.set_ticklabels(['Class 0', 'Class 1']) 
ax.xaxis.set_ticklabels(['Class 0', 'Class 1']) 

plt.title("Confusion matrix", size = 18)
# Out:
# Text(0.5, 1.0, 'Confusion matrix')

# %% [markdown]
# Come possiamo vedere anche graficamente la maggior parte dei valori viene assegnata alla classe corretta il ché vuol dire che il nostro classificatore riesce a distinguere bene le due classi. Probabilmente questo classificatore potrebbe essere migliorato facendolo lavorare su un numero maggiore di dati; avendo più dati inoltre si potrebbe aumentare anche il numero di parametri della rete sfruttando a pieno i metodi del Deep Learning.

# %% [markdown]
# <a id="esercizio3"></a>
# ## Esercizio regressione polinomiale

# %% [markdown]
# Leggendo il dataset `data/position_salaries.csv` effettuare una regressione dei dati di salario in base al livello (espresso nella forma di anni di esperienza).

# %%
dati = pd.read_csv("data/position_salaries.csv")
dati
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %% [markdown]
# Come possiamo vedere anche ad occhio non ci sono valori mancanti. Come da prassi partiamo con il vedere come sono legate gli anni di esperienza al salario.

# %% [markdown]
# ### Esplorazione variabili
#
# Per prima cosa utilizziamo quindi la funzione reg_plot di seaborn in combinazione a statsmodel che ci consente di performare una regressione lineare sui dati. Visto che siamo in fase di esplorazione dei dati non ci occuperemo di guardare ordini maggiori. Nella legenda del grafico inseriamo inoltre il p-value della regressione, l'indice $r^2$ e l'equazione della retta che descrive la relazione che intercorre tra le due variabili

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(dati['Level'], y = dati['Salary'])

plt.figure(figsize = (6,6))
sns.regplot(x = dati['Level'], y = dati['Salary'], scatter_kws={"s": 30}, ci = 95, color = "#FFAD89", order = 1,
            line_kws={'label': r"y={0:.2f}x+{1:.2f}, $r^2$ = {2:.2f}, p = {3:.1g}".format(slope, intercept, r_value, p_value)})
plt.xticks(size = 12)
plt.yticks(size = 12)
plt.xlabel("Level", size = 15)
plt.ylabel("Salary", size = 15)
plt.grid()
plt.legend(fontsize=12, bbox_to_anchor=(1.01, 0.6, 1.1, 0.2), loc='upper left')

# %% [markdown]
# Come vediamo il p-value è inferiore al valore di 0.05, ciò vuol dire che la relazione di linearità tra le variabili è statisticamente significativa. Inoltre il valore di $r^2$ è già molto alto, il ché lascia supporre che inserendo anche degli ordini maggiori si possa trovare un modello che riesca a performare meglio. Dedichiamoci quindi nella prossima sottosezione ad approfondire le regressioni polinomiali

# %% [markdown]
# ### Regressioni polinomiali
#
# Costruiamo quindi la funzione **custom_reg**. Come si può notare questa funzione consente di applicare un regressione lineare specificando la variabile indipendente di partenza e la variabile dipendente. In particolare sono presenti inoltre altri parametri che permettono di estendere questa funzione in modo da inserire altri ordini. In particolare:
#
# - **x**: la variabile indipendente da considerare
#
# - **y**: la variabile dipendente
#
# - **max_order**: consente di definire il grado della regressione polinomiale a cui arrivare. Vengono quindi create (*max_order - 1*) colonne che contengono la variabile dipendente elevata a tutti i gradi intermedi. Ad esempio definendo max_grad = 3 verranno aggiunte 2 colonne al dataset iniziale. La prima conterrà $x^2$ mentre la seconda conterrà $x^3$. Il valore di default è 3 per creare una regressione polinomiale cubica.
#
# - **exp**: consente di creare una colonna che contiene $e^{x}$. Di default non viene creata nessuna colonna
#
# - **log**: consente di creare una colonna che contiene $log(x)$. Di default non viene creata nessuna colonna
#
# - **custom_func**: consente di creare una colonna che contiene una funzione customizzabile dall'utente. Di default non viene creata nessuna colonna
#
# Nella sua massima generalità il modello sarà quindi:
#
# $$ \hat{y} = \beta_0 + \sum_{i = 1}^{max\_order}\left( \beta_i x^i \right) + \beta_{exp} e^{x} + \beta_{log} \log{x} +  \beta_{cust} custom\_func(x) $$
# Come descritto in precedenza i valori di default consentiranno di poter effettuare solo la regressione polinomiale come richiesto dall'esercizio. Questa funzione permette inoltre di ritornare diverse cose:
#
# - *independent_arr:* array della variabile dipendente con le relative colonne create all'interno della funzione.
#
# - *predictions:* array delle predizioni fatte dal modello, in questo caso avendo solo 10 dati non aveva senso separare in train e test
#
# - *coefficient:* i coeffiecienti $\beta_i, \beta_{exp}, \beta_{log}, \beta_{cust}$ del modello
#
# - *intercept:* l'intercetta $\beta_0$ del modello
#
# - *mae:* il Mean Absolute Error calcolato tra predizioni e valori veri tramite:
#
# $$ MAE = \frac{1}{\# obs} \sum_{i = 1}^{\# obs}\left| \hat{y}_i - y_i \right|  $$
#
# - *r2:* l'indice $r^2$ ottenuto dal modello

# %%
def custom_regr(x, y, max_order = 3, exp = False, log = False, custom_func = False): 
    
    assert max_order != 0, "Devi inserire un valore di max_order > 0"
        
    independent_arr = np.ones((len(x), max_order))
    independent_arr[:,0] = x
    dependent = np.array(y).reshape(-1, 1)

    for i in range(1, max_order):
        independent_arr[:,i] = x ** (i + 1) 

    if exp:
        exp_fun = np.ones((independent_arr.shape[0], 1))
        exp_fun[:,0] = np.exp(x)
        independent_arr = np.append(independent_arr, exp_fun, axis=1)
    if log:
        log_fun = np.ones((independent_arr.shape[0], 1))
        log_fun[:,0] = np.log(x)
        independent_arr = np.append(independent_arr, log_fun, axis=1)
    
    if custom_func:
        cust_fun = np.ones((independent_arr.shape[0], 1))
        cust_fun[:,0] = custom_func(x)
        independent_arr = np.append(independent_arr, cust_fun, axis=1)
    reg = linear_model.LinearRegression()
    
    reg.fit(independent_arr,  y)
    
    predictions = reg.predict(independent_arr)
    coefficient = reg.coef_
    intercept = reg.intercept_
    mae = mean_absolute_error(predictions,  y)
    r2 = r2_score(predictions,  y)
    
    print('Coefficients:', np.round(coefficient, 2))
    print('Intercept:', round(intercept, 2))
    print('Mean Absolute Error: {0:.2f}'.format(mae))
    print('Coefficient of determination: {0:.2f}'.format(r2))

    return independent_arr, predictions, coefficient, intercept, mae, r2

# %% [markdown]
# Di seguito proponiamo anche l'esempio di una funzione customizzabile da poter passare come parametro a custom_func

# %%
def cust_fun(x):
    return np.sin(x)

# %% [markdown]
# Richiamiamo quindi le fa funzione che abbiamo creato in modo da farci ritornare tutti i parametri. Utilizziamo come benchmark una regressione polinomiale cubica del tipo:
#
# $$ \hat{y} = \beta_0 + \beta_1 x + \beta_2 x^2 + \beta_3 x^3 $$
#
# Per come è stata costruita la funzione ci verranno quindi ritornati l'intercetta $\beta_0$ e i valori dei coefficienti delle potenze di x: $\beta_1, \beta_2, \beta_3$ sotto forma di numpy array.

# %%
arrayfin, pred, coef, inter, mae, r2 = custom_regr(dati['Level'], dati['Salary'], max_order = 3, 
                                                   exp = False, log = False, custom_func = False)
# Out:
# Coefficients: [180664.34 -48548.95   4120.05]
# Intercept: -121333.33
# Mean Absolute Error: 34790.21
# Coefficient of determination: 0.98

# %% [markdown]
# Come notiamo vengono stampati a schermo tutti i valori descritti nel paragrafo precedente. Utilizzando solo una funzione di fitting cubica si riesce a raggiungere un valore di $r^2$ di 0.98 che è un valore veramente alto. Disegniamo in uno scatter plot le previsioni rispetto ai valori veri. Ovviamente più le previsioni si adattano ai valori veri più i punti sullo scatter plot tenderanno a stare sulla diagonale. Proponiamo quindi anche la retta di regressione lineare.

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(pred.reshape(1,-1), y = dati['Salary'])

fig, ax = plt.subplots(figsize = (6, 6))

sns.regplot(x = pred.reshape(1,-1), y = dati['Salary'], scatter_kws={"s": 30}, ci = 95, color = "#FFAD89", order = 1,
            line_kws={'label': r"y={0:.1f}x+{1:.1f}, $r^2$ = {2:.2f}".format(slope, intercept, r_value)})
plt.xticks(size = 12)
plt.yticks(size = 12)

plt.xlim(0, 1.01e6)
plt.ylim(0, 1.01e6)

ax.ticklabel_format(axis = 'both', style = 'sci', scilimits = (0,0))

plt.xlabel("Predictions", size = 15)
plt.ylabel("True Value", size = 15)
plt.grid()
plt.legend(fontsize=12, bbox_to_anchor=(1.01, 0.6, 1.1, 0.2), loc='upper left')
# Out:
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:174: RuntimeWarning: invalid value encountered in sqrt
#   t = r * np.sqrt(df / ((1.0 - r + TINY)*(1.0 + r + TINY)))
# /Users/christianuccheddu/opt/anaconda3/envs/environment/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py:176: RuntimeWarning: invalid value encountered in sqrt
#   slope_stderr = np.sqrt((1 - r**2) * ssym / ssxm / df)

# %% [markdown]
# Come descritto in precedenza  l'accordo tra le previsioni e i dati reali è pressoché perfetto, si ha infatti che il coefficiente angolare della retta di regressione lineare è 1 con ordinata all'origine nulla. Osservando l'intervallo di confidenza al 95\% costruito intorno alla retta si vede infatti che quasi tutti e 10 i valori stanno dentro l'intervallo, confermando quindi la bontà del modello.
